# %% [markdown]
# <a href="https://colab.research.google.com/github/SaneekantiAnilkumar/Data-science-project-1/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
sb.regplot(x='total_bill',y ='tip',data=df)
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
sb.pairplot(df)
plt.show()

# %%
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
selected_vars = ['total_bill', 'tip',]
sb.pairplot(df, vars=selected_vars)
plt.show()

# %%
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
sb.pairplot(df,hue ='size')
plt.show()

# %%
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
sb.pairplot(df,hue ='size",palette="hus1")

plt.show()

# %%
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
sb.pairplot(df,diag_kind='kde')
plt.show()

# %%
sb.pairplot(df,kind='reg')
plt.show()
